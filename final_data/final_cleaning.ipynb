# %%
from google.colab import drive
drive.mount('/content/gdrive') 
# %cd "/content/gdrive/My Drive/Econ488Paper/final_data"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Econ488Paper/final_data

# %%
import pandas as pd
import numpy as np 
from datetime import datetime
from numpy.linalg import norm 
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("final_cases.csv", index_col = 0)      
mask_data = pd.read_csv("cleaned_mask_data.csv", index_col = 0) 
demo_data = pd.read_csv("age_data.csv", index_col = 0)
race_data = pd.read_csv("demographics_race.csv", index_col = 0)

demo_data.columns = demo_data.columns.str.lower() 
mask_data.columns = mask_data.columns.str.lower()    
race_data.columns = race_data.columns.str.lower()

# %%
data.head(2)
# Out:
#          date                    county  ...  treatment_indicator  x_cases
# 0  2020-07-10  Abbeville South Carolina  ...                    0      141
# 1  2020-07-11  Abbeville South Carolina  ...                    0      150
#
# [2 rows x 8 columns]

# %%
mask_data.head(2)
# Out:
#    countyfp  never  rarely  sometimes  frequently  always  similarity
# 0     46093  0.123   0.078      0.161       0.214   0.425    0.000000
# 1     20083  0.126   0.075      0.163       0.225   0.412    0.017664

# %%
demo_data.head(2)
# Out:
#     year           county  pct_18_29
# 11    12  Autauga Alabama   0.147917
# 23    12  Baldwin Alabama   0.127324

# %%
race_data.head(2)
# Out:
#              ctyname  pct_white  ...  pct_asian  pct_pacific_island
# 209  Autauga Alabama   0.762623  ...   0.011742            0.001038
# 437  Baldwin Alabama   0.874410  ...   0.010661            0.000690
#
# [2 rows x 6 columns]

# %%
len(data.fips.unique()), len(demo_data.county.unique()), len(mask_data.countyfp.unique())
# Out:
# (2971, 2971, 2971)

# %%
unique_counties = set(data.county.unique()).intersection(set(race_data.ctyname.unique()))

# %%
len(unique_counties)
# Out:
# 2971

# %%
race_data = race_data[race_data.ctyname.isin(unique_counties)] 

len(race_data.ctyname.unique())
# Out:
# 2971

# %%
race_data["county"] = race_data.ctyname 
race_data.drop(["ctyname"], axis = 1, inplace = True)

# %%
county_fips = data[["county", "fips"]].drop_duplicates() 

demo_temp = demo_data.merge(county_fips, how = "left", on = "county") 
race_data = race_data.merge(county_fips, how = "left", on = "county")

# %%
demo_temp.head()
# Out:
#    year           county  pct_18_29  fips
# 0    12  Autauga Alabama   0.147917  1001
# 1    12  Baldwin Alabama   0.127324  1003
# 2    12  Barbour Alabama   0.153326  1005
# 3    12     Bibb Alabama   0.156024  1007
# 4    12   Blount Alabama   0.139211  1009

# %%
race_data.head()
# Out:
#    pct_white  pct_black  ...           county  fips
# 0   0.762623   0.201131  ...  Autauga Alabama  1001
# 1   0.874410   0.087769  ...  Baldwin Alabama  1003
# 2   0.491534   0.482298  ...  Barbour Alabama  1005
# 3   0.767661   0.212691  ...     Bibb Alabama  1007
# 4   0.958254   0.016913  ...   Blount Alabama  1009
#
# [5 rows x 7 columns]

# %%
mask_temp = mask_data.drop(["similarity"], axis = 1)

# %%
meade = demo_data[demo_data.county == "Meade South Dakota"]

# %%
meade
# Out:
#      year              county  pct_18_29
# 551    12  Meade South Dakota    1.52033

# %%
######## MATCH ON MEDIAN AGE ###########

# %%
mask_data = mask_data.drop(["similarity"], axis = 1)

# %%
mask_data.head()
# Out:
#    countyfp  never  rarely  sometimes  frequently  always
# 0     46093  0.123   0.078      0.161       0.214   0.425
# 1     20083  0.126   0.075      0.163       0.225   0.412
# 2     21213  0.137   0.066      0.162       0.208   0.426
# 3     46107  0.131   0.067      0.147       0.225   0.431
# 4     13269  0.126   0.069      0.182       0.201   0.422

# %%
mask_data["fips"] = mask_data.countyfp
mask_data.drop(["countyfp"], axis = 1, inplace = True)

# %%
county_data = mask_data.merge(race_data, how = "left", on = "fips")

# %%
county_data.head()
# Out:
#    never  rarely  sometimes  ...  pct_asian  pct_pacific_island               county
# 0  0.123   0.078      0.161  ...   0.010306            0.000918   Meade South Dakota
# 1  0.126   0.075      0.163  ...   0.042921            0.000000      Hodgeman Kansas
# 2  0.137   0.066      0.162  ...   0.008454            0.000915     Simpson Kentucky
# 3  0.131   0.067      0.147  ...   0.008360            0.000464  Potter South Dakota
# 4  0.126   0.069      0.182  ...   0.008728            0.000125       Taylor Georgia
#
# [5 rows x 12 columns]

# %%
county_data.columns
# Out:
# Index(['never', 'rarely', 'sometimes', 'frequently', 'always', 'fips',
#        'pct_white', 'pct_black', 'pct_american_indian', 'pct_asian',
#        'pct_pacific_island', 'county'],
#       dtype='object')

# %%
county_data = county_data[['fips', 'county', 'never', 'rarely', 'sometimes', 'frequently', 'always', 
                            'pct_white', 'pct_black', 'pct_american_indian', 'pct_asian',
                            'pct_pacific_island']]   

county_data.head()
# Out:
#     fips               county  ...  pct_asian  pct_pacific_island
# 0  46093   Meade South Dakota  ...   0.010306            0.000918
# 1  20083      Hodgeman Kansas  ...   0.042921            0.000000
# 2  21213     Simpson Kentucky  ...   0.008454            0.000915
# 3  46107  Potter South Dakota  ...   0.008360            0.000464
# 4  13269       Taylor Georgia  ...   0.008728            0.000125
#
# [5 rows x 12 columns]

# %%
demo_data.head()
# Out:
#     year           county  pct_18_29
# 11    12  Autauga Alabama   0.147917
# 23    12  Baldwin Alabama   0.127324
# 35    12  Barbour Alabama   0.153326
# 47    12     Bibb Alabama   0.156024
# 59    12   Blount Alabama   0.139211

# %%
county_data = county_data.merge(demo_data[["county", "pct_18_29"]], how = "left", on = "county")  
county_data.head()
# Out:
#     fips               county  never  ...  pct_asian  pct_pacific_island  pct_18_29
# 0  46093   Meade South Dakota  0.123  ...   0.010306            0.000918   1.520330
# 1  20083      Hodgeman Kansas  0.126  ...   0.042921            0.000000   1.511706
# 2  21213     Simpson Kentucky  0.137  ...   0.008454            0.000915   1.491008
# 3  46107  Potter South Dakota  0.131  ...   0.008360            0.000464   1.492336
# 4  13269       Taylor Georgia  0.126  ...   0.008728            0.000125   1.476309
#
# [5 rows x 13 columns]

# %%
norms = np.linalg.norm(demo_data.iloc[:, 2:] - demo_data.iloc[0][2: ].astype(float), ord = 2, axis = 1)

# %%
county_data["similarity"] = norms

# %%
county_data.head(3)
# Out:
#     fips              county  never  ...  pct_pacific_island  pct_18_29  similarity
# 0  46093  Meade South Dakota  0.123  ...            0.000918   1.520330    0.000000
# 1  20083     Hodgeman Kansas  0.126  ...            0.000000   1.511706    0.020594
# 2  21213    Simpson Kentucky  0.137  ...            0.000915   1.491008    0.005408
#
# [3 rows x 14 columns]

# %%
county_data = county_data.sort_values(by = ["similarity"]) 
county_data.head()
# Out:
#      fips               county  ...  pct_18_29  similarity
# 0   46093   Meade South Dakota  ...   1.520330    0.000000
# 27  46069    Hyde South Dakota  ...   1.518832    0.000047
# 12  46033  Custer South Dakota  ...   1.495430    0.000385
# 8   13185      Lowndes Georgia  ...   1.482624    0.000426
# 32  38003  Barnes North Dakota  ...   1.504081    0.000605
#
# [5 rows x 14 columns]

# %%
county_data.pct_18_29 /= 10 

county_data.head()
# Out:
#      fips               county  ...  pct_18_29  similarity
# 0   46093   Meade South Dakota  ...   0.152033    0.000000
# 27  46069    Hyde South Dakota  ...   0.151883    0.000047
# 12  46033  Custer South Dakota  ...   0.149543    0.000385
# 8   13185      Lowndes Georgia  ...   0.148262    0.000426
# 32  38003  Barnes North Dakota  ...   0.150408    0.000605
#
# [5 rows x 14 columns]

# %%
county_data.to_csv("county_demographics_final.csv")
